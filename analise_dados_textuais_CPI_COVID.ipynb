# %% [markdown]
# <a href="https://colab.research.google.com/github/rgaguiar/data_science_Py/blob/main/analise_dados_textuais_CPI_COVID.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análise de dados textuais do relatório final da CPI da COVID
# por [Rafael Aguiar](https://github.com/rgaguiar)

# %% [markdown]
# O relatório final da CPI da covid é um documento com as investigações e apurações de supostas omissões e irregularidades  nas ações do governo federal do presidente Jair Bolsonaro (sem partido) durante a pandemia de covid-19 no Brasil.
# Aqui iremos analisar:
# * Quais são os sentimentos/palavras mais citadas no relatório?
# * Quais os termos mais relevantes no documento?
# * Quais são as palavras que mais ocorrem juntas? Co-Ocorrência ***

# %%
# instalando a biblioteca para leitura do pdf
# !pip install pymupdf
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pymupdf
#   Downloading PyMuPDF-1.20.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.8 MB)
#      |████████████████████████████████| 8.8 MB 5.3 MB/s
# Installing collected packages: pymupdf
# Successfully installed pymupdf-1.20.2

# %%
# Importação das bibliotecas utilizadas
import nltk
from nltk.corpus import stopwords
from nltk.probability import FreqDist
from wordcloud import WordCloud
import string
import re
from nltk.corpus import words

# %%
# importando o arquivo que sera analisado
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c4240cf7-51e0-4f7b-9169-2b45bf612968" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c4240cf7-51e0-4f7b-9169-2b45bf612968">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving relatorio-final-renan-calheiros-cpi.pdf to relatorio-final-renan-calheiros-cpi.pdf

# %% [markdown]
# O relatório foi extraído do site do senado, que pode ser acessado publicamente no [link](https://static.poder360.com.br/2021/10/relatorio-final-renan-calheiros-cpi.pdf). Após realizar o download do documento, tratamos o pdf de tal forma que possamos fazer uso de técnicas de processamento de linguagem natural (NPL), tais como:
#
# * Tratamento do PDF
# * Remoção das pontuações
# * Tokenização
# * Contagem de palavras no documento
# * Remoção de stopwords
# * Distribuição de frequência das palavras
# * Wordcloud do relatório

# %% [markdown]
# # Tratamento do PDF

# %%
# lendo o pdf
import fitz
with fitz.open("relatorio-final-renan-calheiros-cpi.pdf") as pdf:
    texto = ""
    for pagina in pdf:
        texto += pagina.get_text()

# %%
# removendo o caractere \n
texto_str = texto.rstrip()

#ajustando os espacos
texto_str = texto.replace('\n', ' ')

# texto em minusculo
texto_str = texto_str.lower()

# %%
# por questão de rederização esse saída foi suprimida
#texto_str

# %% [markdown]
# # Removendo pontuações do documento
# Após realizar o tratamento do PDF, iremos começar a limpeza do texto. Para isso, será retirado toda pontuação desnecessária.

# %%
# remoção da pontuação
text_sem_pontuacao = ''.join([p for p in texto_str if p not in string.punctuation ])

# por questão de rederização esse saída foi suprimida
#print(text_sem_pontuacao)

# %%
# \w remove caractere alfanumerico
# \s remove com caracter único de espaço em branco (espaço, nova linha, retorno, tab, from)
# \d remove Encontra dígitos [0-9]

frase_limpa = re.sub(r'[^\w\s\d]','', text_sem_pontuacao) 

# por questão de rederização esse saída foi suprimida
#frase_limpa

# %% [markdown]
# # Tokenização do documento
# Agora o texto será separado em palavras únicas, para que seja possível calcular a quantidade de palavras, frequência das palavras e verificação de stopwords.

# %%
# tokenização
nltk.download('punkt')
tokenizacao_palavras = nltk.word_tokenize(frase_limpa)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# # Quantidade de Palavras

# %%
len(set(tokenizacao_palavras))
# Out:
# 23547

# %% [markdown]
# # Remoção de stopwords
# Aqui será realizado o download das stopwords em português. As stopwords são palavras que quando retiradas de um texto o sentido não é alterado, por isso iremos removê-las do texto, para trabalhar com uma base menor.
# Primeiramente, vamos acrescentar mais palavras as stopwords padrão antes de fazer a remoção de fato das stopwords.

# %%
# remoção das Stopwords
nltk.download('stopwords')
stopwords = stopwords.words("portuguese")
stop_words = ['sobre', 'sr', 'ser', 'nº', 'ainda', 'r', 'uso', 'dia', 'ter', 'qualquer', 
              'assim', 'então', 'porte', 'havia', 'porque', 'apenas', 'outras', 'disso', 
              'após', 'al', 'pode', 'disse', 'fez', 'nesse', 'desse', 'i', 'final', 'outro', 
              'total', 'sra', 'vez', 'aqui', '20', 'disse', 'sob', 'v', 'desde', '10', 'ii', 
              'dessas', 'diz', 'quanto', '00', '2º', 'mesma', 'pois', 'quais', 'cada', '15', 
              'todo', 'apartir', 'desta', 'deve', '3', 'outra', 'ms', '2'] + stopwords

palavras_sem_stop = [p for p in tokenizacao_palavras if p not in stop_words]
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
print(palavras_sem_stop)
# Out:
# ['senado', 'federal', 'relatório', 'cpi', 'pandemia', 'comissão', 'parlamentar', 'inquérito', 'pandemia', 'instituída', 'requerimentos', '1371', '1372', '2021', 'relatório', 'mesa', 'diretora', 'senado', 'federal', 'biênio', '20212022', 'senador', 'rodrigo', 'pacheco', 'presidente', 'senador', 'veneziano', 'vital', 'rêgo', 'primeiro', 'vicepresidente', 'senador', 'romário', 'segundo', 'vicepresidente', 'senador', 'irajá', 'primeiro', 'secretário', 'senador', 'elmano', 'férrer', 'segundo', 'secretário', 'senador', 'rogério', 'carvalho', 'terceiro', 'secretário', 'senador', 'weverton', 'rocha', 'quarto', 'secretário', 'senador', 'jorginho', 'mello', 'primeiro', 'suplente', 'senador', 'luiz', 'carmo', 'segundo', 'suplente', 'senadora', 'eliziane', 'gama', 'terceiro', 'suplente', 'senador', 'zequinha', 'marinho', 'quarto', 'suplente', 'ilana', 'trombka', 'diretorageral', 'gustavo', 'sabóia', 'vieira', 'secretáriogeral', 'mesa', 'secretáriogeral', 'mesa', 'cpipandemia', 'cpi', 'pandemia', 'instituída', 'requerimentos', '1371', '1372', '2021', 'finalidade', 'apurar', 'prazo', '90', 'dias', 'ações', 'omissões', 'governo', 'federal', 'enfrentamento', 'pandemia', 'covid19', 'brasil', 'especial', 'agravamento', 'crise', 'sanitária', 'amazonas', 'ausência', 'oxigênio', 'pacientes', 'internados', 'possíveis', 'irregularidades', 'contratos', 'fraudes', 'licitações', 'superfaturamentos', 'desvio', 'recursos', 'públicos', 'assinatura', 'contratos', 'empresas', 'fachada', 'prestação', 'serviços', 'genéricos', 'fictícios', 'outros', 'ilícitos', 'valendo', 'recursos', 'originados', 'união', 'federal', 'bem', 'ações', 'omissões', 'cometidas', 'administradores', 'públicos', 'federais', 'estaduais', 'municipais', 'trato', 'coisa', 'pública', 'durante', 'vigência', 'calamidade', 'originada', 'pandemia', 'coronavírus', 'sarscov2', 'limitado', 'fiscalização', 'recursos', 'união', 'repassados', 'demais', 'entes', 'federados', 'ações', 'prevenção', 'combate', 'pandemia', 'covid19', 'excluindo', 'matérias', 'competência', 'constitucional', 'atribuídas', 'estados', 'distrito', 'federal', 'municípios', 'relatório', 'votado', '26', 'outubro', '2021', 'senador', 'omar', 'aziz', 'presidente', 'senador', 'randolfe', 'rodrigues', 'vicepresidente', 'senador', 'renan', 'calheiros', 'relator', 'cpipandemia', 'cpi', 'pandemia', 'bloco', 'parlamentar', 'unidos', 'brasil', 'mdb', 'republicanos', 'pp', 'titulares', 'eduardo', 'braga', 'mdb', 'renan', 'calheiros', 'mdb', 'luis', 'carlos', 'heinze', 'pp', 'suplentes', 'jader', 'barbalho', 'mdb', 'flávio', 'bolsonaro', 'patriota', 'bloco', 'parlamentar', 'podemospsdbpsl', 'podemos', 'psdb', 'psl', 'titulares', 'eduardo', 'girão', 'podemos', 'tasso', 'jereissati', 'psdb', 'suplente', 'marcos', 'val', 'podemos', 'psd', 'titulares', 'omar', 'aziz', 'psd', 'otto', 'alencar', 'psd', 'suplente', 'angelo', 'coronel', 'psd', 'bloco', 'parlamentar', 'vanguarda', 'dem', 'pl', 'psc', 'titulares', 'marcos', 'rogério', 'dem', 'jorginho', 'mello', 'pl', 'suplente', 'fernando', 'bezerra', 'coelho', 'mdb', 'bloco', 'parlamentar', 'resistência', 'democrática', 'pt', 'pros', 'titular', 'humberto', 'costa', 'pt', 'suplente', 'rogério', 'carvalho', 'pt', 'pdtcidadaniarede', 'rede', 'pdt', 'cidadania', 'titular', 'randolfe', 'rodrigues', 'rede', 'suplente', 'alessandro', 'vieira', 'cidadania', 'sumário', '1', 'introdução', '9', 'antecedentes', 'requerimento', 'instauração', 'cpi', 'fato', 'determinado', 'objeto', 'cpi', '31', 'instauração', '32', 'composição', '22', '33', 'objetivos', '24', '4', 'plano', 'trabalho', '26', '5', 'desenvolvimento', 'trabalhos', 'comissão', '28', '6', 'análise', '32', '61', 'gabinete', 'paralelo', '34', '62', 'imunidade', 'rebanho', '50', '63', 'tratamento', 'precoce', 'medicamentos', 'ineficazes', '58', '631', 'validade', 'científica', 'tratamento', 'precoce', 'medicamentos', 'ratificados', 'autoridades', 'sanitárias', 'brasileiras', '63', '632', 'político', 'razões', 'insistência', 'tratamento', 'precoce', '7 ...

# %% [markdown]
# # Verificando as palavras com mais frequência
# Após realizar a limpeza do texto, é possível checar o número de aparições das principais palavras. A função *.most_common* da biblioteca *nltk* irá retornar as 20 palavras que mais aparecem no texto.

# %%
# verificando a frequencia das palavras (top 10)
fdist = FreqDist(palavras_sem_stop)
fdist.most_common(20)
# Out:
# [('saúde', 1643),
#  ('ministério', 1009),
#  ('2021', 916),
#  ('art', 820),
#  ('2020', 797),
#  ('federal', 744),
#  ('covid19', 706),
#  ('pandemia', 686),
#  ('presidente', 647),
#  ('tratamento', 633),
#  ('governo', 566),
#  ('lei', 533),
#  ('brasil', 524),
#  ('contra', 489),
#  ('empresa', 472),
#  ('cpi', 451),
#  ('disponível', 426),
#  ('precoce', 420),
#  ('pessoas', 419),
#  ('acesso', 394)]

# %% [markdown]
# Plot da distribuição das 20 palavras mais frequentes (geradas em fdist.plot()):

# %%
# Grafico de distribuicao das palavras
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5))
fdist.plot(20,cumulative=False);

# %% [markdown]
# # Gerando a wordcloud do relatório

# %% [markdown]
# Plot da nuvem de palavras:

# %%
# Wordcloud
wc = WordCloud()
img = wc.generate_from_text(' '.join(palavras_sem_stop))
plt.figure(figsize=(10,5))
plt.imshow(wc, interpolation="bilinear")
plt.axis('off')
img.to_file('worcloud.jpeg');

# %% [markdown]
# Podemos ver que os termos mais usandos no relatório final da CPI da COVID-19 são:  tratamento, precoce, ministério, saúde, vacina, empresa, médico, CPI, dentre outros.
#
# Esse projeto é uma pequena aplicação do que pode ser feito com uso de técnicas Processamento de Linguagem Natural-NPL (ou *NPL em inglês para Neural Processor Language*)
